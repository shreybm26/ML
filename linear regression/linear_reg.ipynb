# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
from sklearn import linear_model

# %%
df=pd.read_csv("canada_per_capita_income.csv")
df.head(3)
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484

# %%
plt.scatter(df.year, df["per capita income (US$)"], color='red', marker='+')
plt.xlabel("Year")
plt.ylabel("per capita income (US$)")
plt.figure(figsize=(5,3))

plt.show()

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['year']], df["per capita income (US$)"])

plt.scatter(df.year, df["per capita income (US$)"], color='red', marker='+')
plt.xlabel("Year")
plt.ylabel("per capita income (US$)")
# plt.figure(figsize=(5,3))

plt.plot(df.year, reg.predict(df[['year']]), color='blue')
plt.plot(df.year, df["per capita income (US$)"], color='black')

plt.figure(figsize=(2,3))

# %%
reg.predict([[2020]])
# Out:
# c:\Users\shrey\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41288.69409442])

# %%
d=pd.read_csv("income.csv")
d.head(3)
# Out:
#    year
# 0  1970
# 1  1971
# 2  1972

# %%
p=reg.predict(d)
d["pci"]=p
d.to_csv("pci.csv")
